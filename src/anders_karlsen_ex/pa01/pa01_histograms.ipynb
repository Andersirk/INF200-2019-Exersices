# %%
# -*- coding: utf-8 -*-

#__author__ = "Kåre Johnsen", "Anders Karlsen"
#__email__ = "kajohnse@nmbu.no", "anderska@nmbu.no"

import matplotlib.pyplot as plt
from snakes_and_ladders import multi_game_experiment

# %%
plt.title("1 Player")
plt.ylabel("Frekvens")
plt.xlabel("Antall kast av vinneren")
plt.hist(multi_game_experiment(100, 1, 6969), 30, histtype="stepfilled")
plt.show()

# %%
plt.hist(multi_game_experiment(100, 2, 6969), 30, histtype="stepfilled")
plt.title("2 Players")
plt.ylabel("Frekvens")
plt.xlabel("Antall kast av vinneren")
plt.show()

# %%
plt.hist(multi_game_experiment(100, 4, 6969), 30, histtype="stepfilled")
plt.title("4 Players")
plt.ylabel("Frekvens")
plt.xlabel("Antall kast av vinneren")
plt.show()

# %%
plt.hist(multi_game_experiment(100, 8, 6969), 30, histtype="stepfilled")
plt.title("8 Players")
plt.ylabel("Frekvens")
plt.xlabel("Antall kast av vinneren")
plt.show()
